# %%
import pandas as pd 
df=pd.read_csv('/content/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = "latin-1")

# %%
print(df)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria     2501.0     Population         511.0
# 1              4   Algeria     2501.0     Population        5301.0
# 2              4   Algeria     2901.0    Grand Total         664.0
# 3              4   Algeria     2901.0    Grand Total         674.0
# 4              4   Algeria     2901.0    Grand Total         684.0
# ...          ...       ...        ...            ...           ...
# 68314        181  Zimbabwe     2899.0  Miscellaneous        5142.0
# 68315        181  Zimbabwe     2899.0  Miscellaneous         645.0
# 68316        181  Zimbabwe     2899.0  Miscellaneous         664.0
# 68317        181  Zimbabwe     2899.0  Miscellaneous         674.0
# 68318        181  Zimbabwe     2899.0  Miscellaneous         684.0
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.describe()
# Out:
#            Area Code     Item Code  Element Code          Y2014  \
# count   68319.000000  68318.000000  68318.000000   66559.000000
# mean      126.555848   2686.963948   3818.275740     127.869876
# std       389.198217    145.863820   2209.868596    1492.587518
# min         4.000000   2501.000000    511.000000   -1796.000000
# 25%        46.000000   2562.000000    684.000000       0.000000
# 50%       129.000000   2630.000000   5142.000000       0.070000
# 75%       193.000000   2775.000000   5511.000000       8.000000
# max    100000.000000   2961.000000   5911.000000  176405.000000
#
#                Y2015          Y2016          Y2017          Y2018
# count   66604.000000   66585.000000   66587.000000   66703.000000
# mean      129.154938     130.601687     134.752748     137.277658
# std      1527.145491    1562.264803    1593.331623    1629.747997
# min     -3161.000000   -3225.000000   -1582.000000   -3396.000000
# ...

# %%
gk = df.groupby('Element')
gk.sum()
# Out:
#                                         Area Code   Item Code  Element Code  \
# Element
# Domestic supply quantity                   739491  15881695.0    31397823.0
# Export Quantity                            624223  13115216.0    28827947.0
# Fat supply quantity (g/capita/day)         703886  15130245.0     3840660.0
# Feed                                       183965   3926435.0     8082744.0
# Food                                       691987  14876942.0    28450686.0
# Food supply (kcal/capita/day)              702741  15095417.0     3719728.0
# Food supply quantity (kg/capita/yr)        686733  14752397.0     3539760.0
# Import Quantity                            717611  15413556.0    32212751.0
# Losses                                     286580   6081074.0    11536996.0
# Other uses (non-food)                      245362   5298938.0    10003914.0
# Processing                                 292698   6419667.0    12381103.0
# ...

# %%
print(df['Area'].unique())
# Out:
# ['Algeria' 'Angola' 'Benin' 'Botswana' 'Burkina Faso' 'Cabo Verde'
#  'Cameroon' 'Central African Republic' 'Chad' 'Comoros' 'Congo'
#  "Côte d'Ivoire" nan 'Djibouti' 'Egypt' 'Eswatini' 'Ethiopia'
#  'Ethiopia PDR' 'Gabon' 'Gambia' 'Ghana' 'Guinea' 'Guinea-Bissau' 'Kenya'
#  'Lesotho' 'Liberia' 'Madagascar' 'Malawi' 'Mali' 'Mauritania' 'Mauritius'
#  'Morocco' 'Mozambique' 'Namibia' 'Niger' 'Nigeria' 'Rwanda'
#  'Sao Tome and Principe' 'Senegal' 'Seychelles' 'Sierra Leone'
#  'South Africa' 'Sudan' 'Sudan (former)' 'Togo' 'Tunisia' 'Uganda'
#  'United Republic of Tanzania' 'Zambia' 'Zimbabwe']

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               1
# Item Code          1
# Item               1
# Element Code       1
# Element            1
# Unit               1
# Y2014           1760
# Y2015           1715
# Y2016           1734
# Y2017           1732
# Y2018           1616
# dtype: int64

# %%
gk = df.groupby(['Y2017','Area'])
gk.sum()
# Out:
#                                        Area Code  Item Code  Element Code  \
# Y2017     Area
# -1582.0   Egypt                              118     5445.0       10144.0
# -1200.0   Mozambique                         144     2532.0        5072.0
# -1159.0   Mozambique                         144     2907.0        5072.0
# -865.0    United Republic of Tanzania        215     2913.0        5072.0
# -860.0    United Republic of Tanzania        215     2556.0        5072.0
# ...                                          ...        ...           ...
#  96443.0  Egypt                               59     2501.0         511.0
#  106400.0 Ethiopia                           238     2501.0         511.0
#  112625.0 Nigeria                            159     2907.0        5301.0
#  117702.0 Nigeria                            159     2907.0        5511.0
#  190873.0 Nigeria                            159     2501.0         511.0
#
# ...

# %%
gk = df.groupby(['Element','Area'])
gk.sum()
# Out:
#                                                 Area Code  Item Code  \
# Element                  Area
# Domestic supply quantity Algeria                      464   311204.0
#                          Angola                       826   316106.0
#                          Benin                       6148   310985.0
#                          Botswana                    2340   313766.0
#                          Burkina Faso               27494   316106.0
# ...                                                   ...        ...
# Tourist consumption      Cabo Verde                  4480   345647.0
#                          Egypt                       5546   251428.0
#                          Kenya                      11172   261986.0
#                          Mauritius                  12467   243857.0
#                          Sao Tome and Principe      16019   223107.0
#
#                                                 Element Code     Y2014  \
# Element                  Area
# ...

# %%
gk = df.groupby(['Y2017','Area'])
gk.sum()
# Out:
#                                        Area Code  Item Code  Element Code  \
# Y2017     Area
# -1582.0   Egypt                              118     5445.0       10144.0
# -1200.0   Mozambique                         144     2532.0        5072.0
# -1159.0   Mozambique                         144     2907.0        5072.0
# -865.0    United Republic of Tanzania        215     2913.0        5072.0
# -860.0    United Republic of Tanzania        215     2556.0        5072.0
# ...                                          ...        ...           ...
#  96443.0  Egypt                               59     2501.0         511.0
#  106400.0 Ethiopia                           238     2501.0         511.0
#  112625.0 Nigeria                            159     2907.0        5301.0
#  117702.0 Nigeria                            159     2907.0        5511.0
#  190873.0 Nigeria                            159     2501.0         511.0
#
# ...

# %%
gk = df.groupby(['Item','Y2015'])
gk.sum()
# Out:
#                             Area Code  Item Code  Element Code    Y2014  \
# Item              Y2015
# Alcohol, Non-Food -2.0            137     2659.0        5072.0      1.0
#                   -1.0            390     5318.0       10471.0     -2.0
#                    0.0          20745   483938.0      964968.0      4.0
#                    1.0           2100    47862.0       95531.0     15.0
#                    2.0            551    10636.0       21977.0      7.0
# ...                               ...        ...           ...      ...
# Yams               7296.0          81     2535.0        5511.0   7119.0
#                    16136.0        159     2535.0        5170.0  16697.0
#                    21000.0        159     2535.0        5142.0  20000.0
#                    44678.0        159     2535.0        5301.0  44151.0
#                    45678.0        159     2535.0        5511.0  45152.0
#
#                               Y2016    Y2017    Y2018
# ...
